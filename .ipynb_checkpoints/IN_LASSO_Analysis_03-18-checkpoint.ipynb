# %% [markdown]
# ### Import Python libraries

# %%
# %matplotlib inline 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from scipy import stats
from scipy.stats import zscore
from sklearn.preprocessing import scale 
from sklearn import cross_validation 
from sklearn.linear_model import Lasso, LassoCV 
from sklearn.metrics import mean_squared_error
# Out:
# /Users/emilyhahn/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ### Load and preprocess data

# %%
### Import data ###
df=pd.DataFrame.from_csv('INCA_data.csv')
display(df)

### Scale IN vals and static vars
for column in df:
    df[column]=scale(df[column])
        
### Set static variables ###
static_vars = df.iloc[:,8:]

### Parse IN values to test independently to prevent covariance
V_cov = [df[['V_m']], df[['V_b']], df[['V_b']], df[['V_err']], df[['V_acc']]]
A_cov = [df[['A_m']], df[['A_b']], df[['A_b']], df[['A_err']], df[['A_acc']]]
# Out:
#                 V_m     A_m     V_b     A_b     V_err    A_err   V_acc  \
# participant
# IN 001       0.0845  0.2914 -0.1171 -0.4261    1.0347   1.2361  0.5000
# IN 002       0.0942  0.2030  0.0281  0.1917    1.0347   1.2361  0.6222
# IN 003       0.2188  0.0448 -0.1220  0.0749    1.1085   1.0652  0.6333
# IN 004       0.2188  0.4115 -0.1052 -0.0198    1.1404   0.8229  0.4889
# IN 005       0.0906  0.0870 -0.0339  0.2469    1.1561   1.0646  0.5556
# IN 006       0.2146  0.1105 -0.0112 -0.0120    1.9368   1.9721  0.5111
# IN 007       0.3710  0.4745 -0.1721  0.2707    0.9597   0.7316  0.4444
# IN 008       0.2202  0.3595 -0.1839 -0.0979    1.2982   1.1456  0.4778
# IN 009       0.1358  0.2989 -0.2116  0.1921    1.4037   0.9793  0.4667
# IN 010       0.3572  0.4473 -0.0203  0.2894    0.9603   0.9796  0.5000
# IN 011       0.0193  0.2569 -0.1405  0.1081  122.7238  27.0472  0.4778
# IN 012       0.5614  0.4588  0.3725  0.0072    1.0482   0.6930  0.6667
# IN 013       0.3286  0.1246  0.1907 -0.1206    0.8953   1.4875  0.5333
# IN 014       0.3329  0.1898  0.1340 -0.0063    0.8994   1.1147  0.5444
# IN 015       0.5744  0.3564  0.1072 -0.1654    0.8970   1.0038  0.7222
# IN 016       0.4992  0.4385  0.1660  0.2112    0.7570   0.8198  0.6111
# IN 017       0.2105  0.4434 -0.0606  0.3914    1.1474   1.0710  0.6222
# IN 018       0.5049  0.4340  0.2474  0.2245    1.1360   0.6342  0.5456
# IN 019       0.4179  0.2944 -0.0396  0.1101    1.2494   1.1556  0.5970
# IN 020       0.5632  0.5051  0.0754  0.2335    0.8484   0.7345  0.5393
# IN 021       0.6171  0.3862 -0.4849 -0.0105    1.0605   0.6117  0.5878
# IN 022       0.2312 -0.1236 -0.0682  0.0755    0.9311   1.2198  0.4685
# IN 023       0.6569  0.1398 -0.6262  0.1334    1.2484   1.2415  0.6248
# IN 024       0.4921  0.3157 -0.5556  0.3181    1.2001   1.2542  0.5722
# participant
# IN 001                1        3
# IN 002                0        1
# IN 003                1        1
# IN 004                6        6
# IN 005                3        2
# IN 006                2        1
# IN 007                2        0
# IN 008                4        7
# IN 009                8        5
# IN 010                5        5
# IN 011                1        2
# IN 012                1        6
# IN 013                4        0
# IN 014                1        6
# IN 015                0        1
# IN 016                9        4
# IN 017                1       10
# IN 018                2        2
# IN 019                3        4
# IN 020                3        3
# IN 021                6        5
# IN 022                0        4
# IN 023                5        4
# IN 024                3        4
# IN 025                0        0
# IN 026                2        3
# IN 027                1        7
# IN 028                3        5
# IN 029                1        3
# IN 030                2        4
# IN 031                4        3
# IN 032                1        5
# IN 033                1        1
# IN 034                2        2
# IN 035                0        4
# IN 036                0        2

# %% [markdown]
# ### Initialize LASSO functions

# %%
def lasso(X,y):
    
    # Generate alphas
    alphas = 10**np.linspace(1,-2,36)*0.5

    # Split train and test data
    X_train, X_test , y_train, y_test = \
    cross_validation.train_test_split(X, y, test_size=.5, random_state=None) 

    # Train and plot lasso model
    lasso = Lasso(max_iter=10000) 
    coefs = [] 

    for a in alphas: 
        lasso.set_params(alpha=a) 
        lasso.fit(X_train, y_train)
        coefs.append(lasso.coef_)

    ax = plt.gca()
    ax.plot(alphas, coefs)
    ax.set_xscale('log')   
    plt.axis('tight') 
    plt.xlabel(r'alpha $\alpha$') 
    plt.ylabel('weights (coefs)')
    plt.title('y = %s | x = static_vars + %s' % (y.name,X.columns[0]))
    ax.legend(labels=pd.Series(X.columns), \
              loc=0, bbox_to_anchor=(1.3, .75)) 
    plt.show()

    # Choose the best alpha using cross validation (CV)
    lassocv = LassoCV(cv=18, max_iter=100000) 
    params = lassocv.fit(X_train, y_train)

    # Refit lasso model
    ref_lasso_cv = lasso.set_params(alpha=lassocv.alpha_) 
    ref_params = lasso.fit(X_train, y_train) 

    # Compute error
    mse = mean_squared_error(y_test, lasso.predict(X_test))

    # CV alpha
    cv_alpha = lassocv.alpha_
    print('MSE: %f \n\nCV alpha: %f \n\nCV params: \n\n%s\n' % (mse, cv_alpha, params))

    # Sparse coef estimates
    sce = pd.Series(lasso.coef_, index=X.columns)
    print('lasso sparse coefficient estimates: \n%s' % sce) 
    
    return

# %%
def lasso_IN(X_group,y_predictor,static_vars):
    for var in X_group:
        y_var = y_predictor
        X_var = pd.concat([var,static_vars], axis=1)
        lasso(X_var,y_var)
    return

# %% [markdown]
# ### Independly test IN values - valence, arousal

# %%
### valence | IN fMRI values (SVM output) vs cog-behav variables
lasso_IN(A_cov,df['V_m'],static_vars)

### arousal | IN fMRI values (SVM output) vs cog-behav variables
lasso_IN(V_cov,df['A_m'],static_vars)
# Out:
# MSE: 1.204523
#
# CV alpha: 0.156493
#
# CV params:
#
# LassoCV(alphas=None, copy_X=True, cv=18, eps=0.001, fit_intercept=True,
#     max_iter=100000, n_alphas=100, n_jobs=1, normalize=False,
#     positive=False, precompute='auto', random_state=None,
#     selection='cyclic', tol=0.0001, verbose=False)
#
# lasso sparse coefficient estimates:
# A_m           0.320861
# Age          -0.000000
# Sex           0.000000
# Race         -0.000000
# Nonaccept    -0.271767
# Goals         0.000000
# Impulse       0.000000
# Awareness     0.000000
# Strategies    0.000000
# Clarity      -0.099283
# dtype: float64
# MSE: 0.941521
#
# CV alpha: 0.332025
#
# CV params:
#
# LassoCV(alphas=None, copy_X=True, cv=18, eps=0.001, fit_intercept=True,
#     max_iter=100000, n_alphas=100, n_jobs=1, normalize=False,
#     positive=False, precompute='auto', random_state=None,
#     selection='cyclic', tol=0.0001, verbose=False)
#
# lasso sparse coefficient estimates:
# A_b           0.0
# Age          -0.0
# Sex          -0.0
# Race          0.0
# Nonaccept    -0.0
# Goals         0.0
# Impulse      -0.0
# Awareness     0.0
# Strategies   -0.0
# Clarity      -0.0
# dtype: float64
# MSE: 1.403514
#
# CV alpha: 0.245902
#
# CV params:
#
# LassoCV(alphas=None, copy_X=True, cv=18, eps=0.001, fit_intercept=True,
#     max_iter=100000, n_alphas=100, n_jobs=1, normalize=False,
#     positive=False, precompute='auto', random_state=None,
#     selection='cyclic', tol=0.0001, verbose=False)
#
# lasso sparse coefficient estimates:
# A_b           0.0
# Age          -0.0
# Sex           0.0
# Race          0.0
# Nonaccept    -0.0
# Goals         0.0
# Impulse      -0.0
# Awareness    -0.0
# Strategies   -0.0
# Clarity       0.0
# dtype: float64
# MSE: 0.993964
#
# CV alpha: 0.435263
#
# CV params:
#
# LassoCV(alphas=None, copy_X=True, cv=18, eps=0.001, fit_intercept=True,
#     max_iter=100000, n_alphas=100, n_jobs=1, normalize=False,
#     positive=False, precompute='auto', random_state=None,
#     selection='cyclic', tol=0.0001, verbose=False)
#
# lasso sparse coefficient estimates:
# A_err        -0.093918
# Age          -0.000000
# Sex          -0.000000
# Race          0.000000
# Nonaccept    -0.000000
# Goals         0.000000
# Impulse      -0.000000
# Awareness     0.000000
# Strategies   -0.000000
# Clarity      -0.000000
# dtype: float64
# MSE: 1.258757
#
# CV alpha: 0.257457
#
# CV params:
#
# LassoCV(alphas=None, copy_X=True, cv=18, eps=0.001, fit_intercept=True,
#     max_iter=100000, n_alphas=100, n_jobs=1, normalize=False,
#     positive=False, precompute='auto', random_state=None,
#     selection='cyclic', tol=0.0001, verbose=False)
#
# lasso sparse coefficient estimates:
# A_acc         0.000000
# Age           0.000000
# Sex          -0.000000
# Race          0.000000
# Nonaccept    -0.272573
# Goals        -0.000000
# Impulse      -0.000000
# Awareness     0.000000
# Strategies   -0.000000
# Clarity      -0.000000
# dtype: float64
# MSE: 1.083230
#
# CV alpha: 0.168452
#
# CV params:
#
# LassoCV(alphas=None, copy_X=True, cv=18, eps=0.001, fit_intercept=True,
#     max_iter=100000, n_alphas=100, n_jobs=1, normalize=False,
#     positive=False, precompute='auto', random_state=None,
#     selection='cyclic', tol=0.0001, verbose=False)
#
# lasso sparse coefficient estimates:
# V_m           0.317916
# Age           0.000000
# Sex          -0.253991
# Race          0.000000
# Nonaccept    -0.000000
# Goals         0.181572
# Impulse      -0.000000
# Awareness     0.000000
# Strategies    0.000000
# Clarity      -0.012136
# dtype: float64
# MSE: 1.420568
#
# CV alpha: 0.190586
#
# CV params:
#
# LassoCV(alphas=None, copy_X=True, cv=18, eps=0.001, fit_intercept=True,
#     max_iter=100000, n_alphas=100, n_jobs=1, normalize=False,
#     positive=False, precompute='auto', random_state=None,
#     selection='cyclic', tol=0.0001, verbose=False)
#
# lasso sparse coefficient estimates:
# V_b           0.000000
# Age           0.000000
# Sex          -0.251594
# Race          0.000000
# Nonaccept     0.000000
# Goals         0.000000
# Impulse       0.000000
# Awareness     0.032335
# Strategies    0.000000
# Clarity       0.138438
# dtype: float64
# MSE: 0.661789
#
# CV alpha: 0.348710
#
# CV params:
#
# LassoCV(alphas=None, copy_X=True, cv=18, eps=0.001, fit_intercept=True,
#     max_iter=100000, n_alphas=100, n_jobs=1, normalize=False,
#     positive=False, precompute='auto', random_state=None,
#     selection='cyclic', tol=0.0001, verbose=False)
#
# lasso sparse coefficient estimates:
# V_b           0.000000e+00
# Age           0.000000e+00
# Sex          -0.000000e+00
# Race          0.000000e+00
# Nonaccept    -0.000000e+00
# Goals         0.000000e+00
# Impulse      -0.000000e+00
# Awareness     0.000000e+00
# Strategies    5.928554e-17
# Clarity      -0.000000e+00
# dtype: float64
# MSE: 1.223400
#
# CV alpha: 0.159034
#
# CV params:
#
# LassoCV(alphas=None, copy_X=True, cv=18, eps=0.001, fit_intercept=True,
#     max_iter=100000, n_alphas=100, n_jobs=1, normalize=False,
#     positive=False, precompute='auto', random_state=None,
#     selection='cyclic', tol=0.0001, verbose=False)
#
# lasso sparse coefficient estimates:
# V_err         0.000000
# Age           0.177651
# Sex          -0.248876
# Race          0.000000
# Nonaccept    -0.000000
# Goals         0.000000
# Impulse       0.000000
# Awareness     0.051821
# Strategies    0.377714
# Clarity       0.000000
# dtype: float64
# MSE: 1.428009
#
# CV alpha: 0.234657
#
# CV params:
#
# LassoCV(alphas=None, copy_X=True, cv=18, eps=0.001, fit_intercept=True,
#     max_iter=100000, n_alphas=100, n_jobs=1, normalize=False,
#     positive=False, precompute='auto', random_state=None,
#     selection='cyclic', tol=0.0001, verbose=False)
#
# lasso sparse coefficient estimates:
# V_acc        -0.000000e+00
# Age           1.630842e-16
# Sex           0.000000e+00
# Race          0.000000e+00
# Nonaccept    -0.000000e+00
# Goals        -0.000000e+00
# Impulse       0.000000e+00
# Awareness     0.000000e+00
# Strategies   -0.000000e+00
# Clarity       0.000000e+00
# dtype: float64
