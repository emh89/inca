# %% [markdown]
# ### Import Python libraries

# %%
# %matplotlib inline 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from scipy import stats
from scipy.stats import zscore
from sklearn.preprocessing import scale 
from sklearn import cross_validation 
from sklearn.linear_model import Lasso, LassoCV 
from sklearn.metrics import mean_squared_error
# Out:
# /Users/emilyhahn/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ### Load and preprocess data

# %%
### Import data ###
df=pd.DataFrame.from_csv('INCA_data_V3.csv',index_col=None)
        
### Set static variables ###
static_vars = df.iloc[:,5:50]

### Parse VR values (until NaN issue resolved) ###
V_VR = [df[['v_sig']]]
A_VR = [df[['a_sig']]]

###-------------###

### Parse VR values to test independently ###
# V_VR = [df[['v_sig']], df[['v_ctrl_lab']]]
# A_VR = [df[['a_sig']], df[['a_ctrl_lab']]] 

# df=df.round(0)
# s=np.all(np.isnan(df))

### Scale IN vals and static vars ###
# for column in df:
#     df[column]=scale(df[column])

# %% [markdown]
# ### Initialize LASSO functions

# %%
def lasso(X,y):
    
    # Generate alphas (lin, log are same space)
    alphas = 10**np.linspace(1,-2,36)*0.5
#     alphas = np.logspace(1,-2,36)*0.5

    # Split train and test data
    X_train, X_test , y_train, y_test = \
    cross_validation.train_test_split(X, y, test_size=.5, random_state=None) 

    # Train and plot lasso model
    lasso = Lasso(max_iter=100000)
    coefs = [] 

    for a in alphas: 
        lasso.set_params(alpha=a) 
        lasso.fit(X_train, y_train)
        coefs.append(lasso.coef_)

    ax = plt.gca()
    ax.plot(alphas, coefs)
    ax.set_xscale('log')   
    plt.axis('tight') 
    plt.xlabel(r'alpha $\alpha$') 
    plt.ylabel('weights (coefs)')
    plt.title('y = %s | x = static_vars + %s' % (y.name,X.columns[0]))
    ax.legend(labels=pd.Series(X.columns), \
              loc=0, bbox_to_anchor=(1.3, .75)) 
    plt.show()

    # Choose the best alpha using cross validation (CV)
    lassocv = LassoCV(cv=18, max_iter=100000) 
    params = lassocv.fit(X_train, y_train)

    # Refit lasso model
    ref_lasso_cv = lasso.set_params(alpha=lassocv.alpha_) 
    ref_params = lasso.fit(X_train, y_train) 

    # Compute error
    mse = mean_squared_error(y_test, lasso.predict(X_test))

    # CV alpha
    cv_alpha = lassocv.alpha_
    print('MSE: %f \n\nCV alpha: %f \n\nCV params: \n\n%s\n' % (mse, cv_alpha, params))

    # Coef estimates
    ce = pd.Series(lasso.coef_, index=X.columns)
    print('lasso coefficient estimates: \n%s' % ce)
        
    # Sparse coef estimates
#     sce = pd.Series(lasso.sparse_coef_, index=X.columns)
#     print('lasso sparse coefficient estimates: \n%s' % sce) 

    print('LASSO params: %s' % ref_params)
    
    return

# %%
def lasso_IN(X_group,y_predictor,static_vars):
    for var in X_group:
        y_var = y_predictor
        X_var = pd.concat([var,static_vars], axis=1)
        lasso(X_var,y_var)
    return

# %% [markdown]
# ### Independly test VR values - valence, arousal

# %%
###---------------------### 
# OPTIMIZATION OBJECTIVE
# (1 / (2 * n_samples)) * ||y - Xw||^2_2 + alpha * ||w||_1 
###---------------------### 

### valence | IN fMRI values (SVM output) vs cog-behav variables
lasso_IN(A_VR,df['v_sig'],static_vars)

### arousal | IN fMRI values (SVM output) vs cog-behav variables
lasso_IN(V_VR,df['a_sig'],static_vars)
# Out:
# MSE: 0.681761
#
# CV alpha: 0.001811
#
# CV params:
#
# LassoCV(alphas=None, copy_X=True, cv=18, eps=0.001, fit_intercept=True,
#     max_iter=100000, n_alphas=100, n_jobs=1, normalize=False,
#     positive=False, precompute='auto', random_state=None,
#     selection='cyclic', tol=0.0001, verbose=False)
#
# lasso coefficient estimates:
# a_sig                          0.189515
# Age                            0.007271
# Sex                           -0.000000
# Race                           0.000000
# Education                     -0.000000
# IQ                             0.005040
# BDI                           -0.112623
# CTQ                            0.031233
# CTQ-EA                         0.035569
# CTQ-PA                         0.000000
# CTQ-SA                         0.000000
# CTQ-EN                         0.022243
# CTQ-PN                        -0.250995
# CTQ-D                         -0.000000
# Nonaccept                      0.058786
# Goals                          0.096063
# Impulse                       -0.028041
# Awareness                     -0.016571
# Strategies                    -0.000000
# Clarity                       -0.000000
# DERS                          -0.033307
# Negative Affect               -0.031662
# Self-Reproach                  0.090769
# Neuroticism                    0.000000
# Positive Affect               -0.071674
# Sociability                   -0.002015
# Activity                       0.141432
# Extraversion                  -0.010199
# Aesthetic Interests           -0.000000
# Intellectual Interests         0.000000
# Unconventionality             -0.021546
# Openness                      -0.000000
# Nonantagonistic Orientation   -0.000000
# Prosocial Orientation          0.122741
# Agreeableness                  0.035986
# Orderliness                    0.004720
# Goal-Striving                  0.000000
# Dependability                 -0.031255
# Conscientiousness              0.000000
# Anxiety                        0.000000
# Depression                    -0.063144
# Self-Reproach.1                0.000000
# STAI                           0.027861
# State                          0.000793
# Trait                         -0.000000
# EHI                            0.006391
# dtype: float64
# <bound method Lasso.get_params of Lasso(alpha=0.001811111111111111, copy_X=True, fit_intercept=True,
#    max_iter=100000, normalize=False, positive=False, precompute=False,
#    random_state=None, selection='cyclic', tol=0.0001, warm_start=False)>
# LASSO params: Lasso(alpha=0.001811111111111111, copy_X=True, fit_intercept=True,
#    max_iter=100000, normalize=False, positive=False, precompute=False,
#    random_state=None, selection='cyclic', tol=0.0001, warm_start=False)
# MSE: 0.260000
#
# CV alpha: 2.630601
#
# CV params:
#
# LassoCV(alphas=None, copy_X=True, cv=18, eps=0.001, fit_intercept=True,
#     max_iter=100000, n_alphas=100, n_jobs=1, normalize=False,
#     positive=False, precompute='auto', random_state=None,
#     selection='cyclic', tol=0.0001, verbose=False)
#
# lasso coefficient estimates:
# v_sig                          0.0
# Age                           -0.0
# Sex                           -0.0
# Race                          -0.0
# Education                     -0.0
# IQ                             0.0
# BDI                           -0.0
# CTQ                           -0.0
# CTQ-EA                         0.0
# CTQ-PA                        -0.0
# CTQ-SA                        -0.0
# CTQ-EN                        -0.0
# CTQ-PN                         0.0
# CTQ-D                         -0.0
# Nonaccept                     -0.0
# Goals                         -0.0
# Impulse                       -0.0
# Awareness                     -0.0
# Strategies                     0.0
# Clarity                        0.0
# DERS                          -0.0
# Negative Affect               -0.0
# Self-Reproach                 -0.0
# Neuroticism                   -0.0
# Positive Affect               -0.0
# Sociability                   -0.0
# Activity                       0.0
# Extraversion                  -0.0
# Aesthetic Interests           -0.0
# Intellectual Interests        -0.0
# Unconventionality             -0.0
# Openness                      -0.0
# Nonantagonistic Orientation    0.0
# Prosocial Orientation         -0.0
# Agreeableness                  0.0
# Orderliness                    0.0
# Goal-Striving                  0.0
# Dependability                  0.0
# Conscientiousness              0.0
# Anxiety                       -0.0
# Depression                    -0.0
# Self-Reproach.1               -0.0
# STAI                          -0.0
# State                         -0.0
# Trait                         -0.0
# EHI                            0.0
# dtype: float64
# <bound method Lasso.get_params of Lasso(alpha=2.6306006439777776, copy_X=True, fit_intercept=True,
#    max_iter=100000, normalize=False, positive=False, precompute=False,
#    random_state=None, selection='cyclic', tol=0.0001, warm_start=False)>
# LASSO params: Lasso(alpha=2.6306006439777776, copy_X=True, fit_intercept=True,
#    max_iter=100000, normalize=False, positive=False, precompute=False,
#    random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
# ###---------------------### 
# # OPTIMIZATION OBJECTIVE
# # (1 / (2 * n_samples)) * ||y - Xw||^2_2 + alpha * ||w||_1 
# ###---------------------### 

# ### valence | IN fMRI values (SVM output) vs cog-behav variables
# lasso_IN(A_VR,df['v_sig'],static_vars)

# ### arousal | IN fMRI values (SVM output) vs cog-behav variables
# lasso_IN(V_VR,df['a_sig'],static_vars)
